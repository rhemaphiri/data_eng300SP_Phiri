# %% [markdown]
# # Lab3: Recommendation System and BERT
# ## 1. Recommendation system overview
# A recommendation system predicts what items a user may like and returns a ranked list of items. Examples:
# | Platform           | User              | Item                  | Example feedback signals                             | Recommendation goal                      |
# | ------------------ | ----------------- | --------------------- | ---------------------------------------------------------------------------- | ---------------------------------------- |
# | Netflix            | viewer            | movie/show            | watch history, watch time, ratings, likes/dislikes, skips, searches          | what to watch next                       |
# | Amazon             | customer          | product               | clicks, purchases, add-to-cart, wish lists, reviews, ratings, search queries | what to buy next                         |
# | Spotify            | listener          | song/playlist/podcast | listening history, skips, replays, likes, playlist saves, follows            | what to listen to next                   |
# | YouTube            | viewer            | video                 | clicks, watch time, likes/dislikes, comments, subscriptions, search history  | what to watch next                       |
# | TikTok / Instagram | viewer            | short video/post      | views, watch time, replays, likes, shares, comments, follows, skips          | what content to show next                |
# | LinkedIn           | professional user | job/post/connection   | clicks, applications, profile views, follows, reactions, connection requests | what jobs, posts, or people to recommend |
#
#
# Recommendation systems may utilize both explicit feedback and implicit feedback as signals:
# | Explicit feedback | Implicit feedback |
# | ----------------- | ----------------- |
# | Star rating       | Click             |
# | Review score      | Watch time        |
# | Like/dislike      | Add to cart       |
# | Survey response   | Purchase          |
#
# There are 3 common recommendation approaches
# 1. Popularity baseline
# 2. Collaborative filltering
# 3. Content-based recommendation
#
#
# ## 2. Recommendation on MovieLens 1M data
# ### 2.1. AWS S3
# Amazon S3 (Simple Storage Service) is AWS’s object storage service.
# - Object = data + metadata
#
# Here are some key terms:
#
# - **Bucket**: the top-level container (globally unique name, for example, `de300-tutorial-data`).
#
# - Object: one stored file (e.g., `movies.dat`).
#
# - Key: the “path-like name” of the object inside a bucket (e.g., `s3://de300-tutorial-data/datasets/movielens/ml-1m.zip`).
#
# - Prefix: the leading part of a key used for organization. S3 doesn’t have real folders; the console shows folder-like views using prefixes.
#
# We may upload/download/modify files on s3 through AWS CLI tool (which may be installed through instruction on [AWS CLI installation](https://docs.aws.amazon.com/cli/latest/userguide/getting-started-install.html)).
#
# Before we use AWS CLI to get access to data on S3, we should set up credentials on the device (your own laptop or EC2). One of the ways to do so is go to the [https://nu-sso.awsapps.com/](https://nu-sso.awsapps.com/), click `Access Keys` and copy AWS Environmental Variables, e.g.,
# ```
#
#
# Some commands that are frequently used:
# 1. List all objects under a prefix
#    ```
#    aws s3 ls s3://dinglin-spring26/
#    ```
# 2. Copy ONE object from S3 to local
#    ```
#    aws s3 cp s3://dinglin-spring26/lab4/ml-1m/movies.dat ./movies.dat
#    ```
#
# 3. Copy a “folder” (prefix) recursively
#    ```
#    aws s3 cp s3://dinglin-spring26/lab4/ml-1m/ ./lab4-data/ --recursive
#    ```
#
# 4. Copy files and folders among different buckets
#    ```
#    aws s3 cp s3://dinglin-spring26/lab4/ml-1m/movies.dat s3://DEST_BUCKET/path/to/movies.dat
#    aws s3 cp s3://dinglin-spring26/lab4/ml-1m/ s3://DEST_BUCKET/some/prefix/ --recursive
#    ```
#
# ### 2.2. Dataset Intro
# MovieLens 1M is a classic benchmark dataset for recommender systems released by the GroupLens Research Project. It contains 1,000,209 ratings (1–5 stars, whole-star only) from 6,040 users on movie IDs up to 3,952, and each user has at least 20 ratings.
#
# ### 2.3. Data Loading
# We will read `ratings.dat` and `movies.dat` from the `ml-1m/` folder. These files use `::` as a delimiter, so we set `engine='python'` in `pandas.read_csv`.
#
# - ratings.dat: (user_id, movie_id, rating, timestamp)
# - movies.dat: (movie_id, title, genres)

# %%
import pandas as pd

DATA_DIR = "/home/ec2-user/lab4/ml-1m/"
RATINGS_FILE = DATA_DIR + "ratings.dat"
MOVIES_FILE = DATA_DIR + "movies.dat"

ratings = pd.read_csv(RATINGS_FILE, sep="::", engine="python",
                      names=["user_id","movie_id","rating","timestamp"])
movies  = pd.read_csv(MOVIES_FILE,  sep="::", engine="python",
                      names=["movie_id","title","genres"], encoding="latin-1")

ratings.head(), movies.head()
# Out:
# (   user_id  movie_id  rating  timestamp
#  0        1      1193       5  978300760
#  1        1       661       3  978302109
#  2        1       914       3  978301968
#  3        1      3408       4  978300275
#  4        1      2355       5  978824291,
#     movie_id                               title                        genres
#  0         1                    Toy Story (1995)   Animation|Children's|Comedy
#  1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
#  2         3             Grumpier Old Men (1995)                Comedy|Romance
#  3         4            Waiting to Exhale (1995)                  Comedy|Drama
#  4         5  Father of the Bride Part II (1995)                        Comedy)

# %% [markdown]
# Implicit recommendation models usually need positive interactions rather than 1–5 star ratings. Here we treat ratings ≥ 4 as a positive signal and create a binary column value=1.0

# %%
pos = ratings[ratings["rating"] >= 4].copy()
pos["value"] = 1.0

# %% [markdown]
# To evaluate recommendation, we hold out each user’s most recent positive interaction as the test item (using timestamp). The remaining positives become training data.

# %%
pos = pos.sort_values(["user_id","timestamp"])
test = pos.groupby("user_id").tail(1)
train = pos.drop(test.index)

train.shape, test.shape
# Out:
# ((569243, 5), (6038, 5))

# %% [markdown]
# Before building sophisticated models, it’s useful to compute a simple baseline: recommend the most frequently liked movies in the training set. This gives you a sanity check for your pipeline.

# %%
top_movies = train.groupby("movie_id")["value"].sum().sort_values(ascending=False)
top10 = top_movies.head(10).index.tolist()
movies[movies["movie_id"].isin(top10)][["movie_id","title","genres"]]
# Out:
#       movie_id                                              title  \
# 257        260          Star Wars: Episode IV - A New Hope (1977)
# 589        593                   Silence of the Lambs, The (1991)
# 604        608                                       Fargo (1996)
# 1178      1196  Star Wars: Episode V - The Empire Strikes Back...
# 1180      1198                     Raiders of the Lost Ark (1981)
# 1192      1210  Star Wars: Episode VI - Return of the Jedi (1983)
# 1959      2028                         Saving Private Ryan (1998)
# 2502      2571                                 Matrix, The (1999)
# 2693      2762                            Sixth Sense, The (1999)
# 2789      2858                             American Beauty (1999)
#
#                                    genres
# 257       Action|Adventure|Fantasy|Sci-Fi
# 589                        Drama|Thriller
# 604                  Crime|Drama|Thriller
# 1178    Action|Adventure|Drama|Sci-Fi|War
# 1180                     Action|Adventure
# 1192  Action|Adventure|Romance|Sci-Fi|War
# 1959                     Action|Drama|War
# 2502               Action|Sci-Fi|Thriller
# 2693                             Thriller
# 2789                         Comedy|Drama

# %% [markdown]
# ### 2.4. ALS (Collborative Filltering)
# Many recommenders (including `implicit ALS`) expect a sparse matrix. We map raw IDs to contiguous indices:
#
# - user2idx: user_id → row index
# - item2idx: movie_id → column index
# Then we create a sparse matrix X_ui with shape [num_users, num_items].

# %%
import numpy as np
from scipy.sparse import coo_matrix

user_ids = train["user_id"].unique()
movie_ids = train["movie_id"].unique()

user2idx = {u:i for i,u in enumerate(user_ids)}
movie_ids = np.array(movie_ids)  # ensure it's a numpy array
item2idx = {int(m): i for i, m in enumerate(movie_ids)}
idx2item = {i: int(m) for i, m in enumerate(movie_ids)}

rows = train["user_id"].map(user2idx).to_numpy()
cols = train["movie_id"].map(item2idx).to_numpy()
data = train["value"].to_numpy().astype(np.float32)
X_ui = coo_matrix((data, (rows, cols)), shape=(len(user_ids), len(movie_ids))).tocsr()

# %%
# !pip install implicit
# Out:
# Collecting implicit
#   Obtaining dependency information for implicit from https://files.pythonhosted.org/packages/bf/48/4781c8fa5ba413a8346926e01ea85d3fec63bc1d887f67c0faaa9d7d6471/implicit-0.7.2-cp311-cp311-manylinux2014_x86_64.whl.metadata
#   Downloading implicit-0.7.2-cp311-cp311-manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy>=1.17.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from implicit) (1.26.0)
# Requirement already satisfied: scipy>=0.16 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from implicit) (1.11.1)
# Requirement already satisfied: tqdm>=4.27 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from implicit) (4.67.3)
# Requirement already satisfied: threadpoolctl in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from implicit) (3.6.0)
# Downloading implicit-0.7.2-cp311-cp311-manylinux2014_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 71.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: implicit
# Successfully installed implicit-0.7.2

# %%
import implicit

model = implicit.als.AlternatingLeastSquares(
    factors=64, regularization=0.01, iterations=20
)

# implicit expects item-user matrix
model.fit(X_ui)
# Out:
# /home/ec2-user/anaconda3/lib/python3.11/site-packages/implicit/cpu/als.py:95: RuntimeWarning: OpenBLAS is configured to use 2 threads. It is highly recommended to disable its internal threadpool by setting the environment variable 'OPENBLAS_NUM_THREADS=1' or by calling 'threadpoolctl.threadpool_limits(1, "blas")'. Having OpenBLAS use a threadpool can lead to severe performance issues here.
#   check_blas_config()
# /home/ec2-user/anaconda3/lib/python3.11/site-packages/implicit/cpu/als.py:95: RuntimeWarning: Intel MKL BLAS is configured to use 2 threads. It is highly recommended to disable its internal threadpool by setting the environment variable 'MKL_NUM_THREADS=1' or by callng 'threadpoolctl.threadpool_limits(1, "blas")'. Having MKL use a threadpool can lead to severe performance issues
#   check_blas_config()
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
u = int(user_ids[0])
u_idx = int(user2idx[u])

# IMPORTANT: pass X_ui[u_idx] (1 row), not the full X_ui
recs = model.recommend(u_idx, X_ui[u_idx], N=10)

# Handle implicit returning either (ids, scores) OR list of pairs
if isinstance(recs, tuple) and len(recs) == 2:
    item_ids, scores = recs
else:
    item_ids = [i for i, s in recs]
    scores  = [s for i, s in recs]

rec_movie_ids = [idx2item[int(i)] for i in item_ids]

rec_df = movies.set_index("movie_id").loc[rec_movie_ids][["title", "genres"]].reset_index()
rec_df["score"] = list(scores)
rec_df
# Out:
#    movie_id                         title  \
# 0       364         Lion King, The (1994)
# 1        34                   Babe (1995)
# 2      1225                Amadeus (1984)
# 3      2081    Little Mermaid, The (1989)
# 4      2078       Jungle Book, The (1967)
# 5       953  It's a Wonderful Life (1946)
# 6      2761        Iron Giant, The (1999)
# 7      1282               Fantasia (1940)
# 8      1259            Stand by Me (1986)
# 9      2087              Peter Pan (1953)
#
#                                         genres     score
# 0                 Animation|Children's|Musical  0.559931
# 1                      Children's|Comedy|Drama  0.438390
# 2                                        Drama  0.412407
# 3  Animation|Children's|Comedy|Musical|Romance  0.395595
# 4          Animation|Children's|Comedy|Musical  0.355815
# 5                                        Drama  0.354737
# 6                         Animation|Children's  0.353277
# 7                 Animation|Children's|Musical  0.352121
# 8                       Adventure|Comedy|Drama  0.351520
# 9         Animation|Children's|Fantasy|Musical  0.340108

# %% [markdown]
# ### 2.5. Evaluation: Recall@K and NDCG@K
# We evaluate each user by checking whether the held-out test movie appears in the top-K recommendations:
#
# - Recall@K: fraction of users whose held-out item is retrieved in top-K.
# - NDCG@K: like Recall@K, but gives higher credit when the item appears closer to rank 1.

# %%
import math

def ndcg_at_k(rank, k):
    if rank is None or rank >= k:
        return 0.0
    return 1.0 / math.log2(rank + 2)

def _get_rec_items(recs):
    # implicit may return (item_ids, scores) OR list of (id, score)
    if isinstance(recs, tuple) and len(recs) == 2:
        item_ids = recs[0]
        return [int(i) for i in item_ids]
    else:
        return [int(i) for i, _ in recs]

def eval_model(model, X_ui, test_df, K=10):
    hits, ndcgs, n = 0, 0.0, 0
    for u, gt in zip(test_df["user_id"], test_df["movie_id"]):
        if (u not in user2idx) or (gt not in item2idx):
            continue

        u_idx = int(user2idx[u])

        # IMPORTANT: pass only this user's row
        recs = model.recommend(u_idx, X_ui[u_idx], N=K)

        rec_items = _get_rec_items(recs)
        gt_idx = int(item2idx[gt])

        if gt_idx in rec_items:
            hits += 1
            ndcgs += ndcg_at_k(rec_items.index(gt_idx), K)

        n += 1

    return {"Recall@K": hits / max(n, 1), "NDCG@K": ndcgs / max(n, 1), "Users": n}

eval_model(model, X_ui, test, K=10)
# Out:
# {'Recall@K': 0.09496188266489891, 'NDCG@K': 0.04822084956475933, 'Users': 6034}

# %% [markdown]
# ### 2.6. Content Embedding with BERT Model

# %%
movies["text"] = movies["title"].fillna("") + " [SEP] " + movies["genres"].fillna("")
movies["text"].head()
# Out:
# 0    Toy Story (1995) [SEP] Animation|Children's|Co...
# 1    Jumanji (1995) [SEP] Adventure|Children's|Fantasy
# 2         Grumpier Old Men (1995) [SEP] Comedy|Romance
# 3          Waiting to Exhale (1995) [SEP] Comedy|Drama
# 4      Father of the Bride Part II (1995) [SEP] Comedy
# Name: text, dtype: object

# %%
import torch
from transformers import AutoTokenizer, AutoModel

device = "cuda" if torch.cuda.is_available() else "cpu"
tok = AutoTokenizer.from_pretrained("bert-base-uncased")
bert = AutoModel.from_pretrained("bert-base-uncased").to(device)
bert.eval()

@torch.no_grad()
def encode_texts(texts, batch_size=64, max_len=64):
    embs = []
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size]
        inp = tok(batch, padding=True, truncation=True, max_length=max_len, return_tensors="pt").to(device)
        out = bert(**inp).last_hidden_state[:,0,:]  # [CLS]
        embs.append(out.cpu())
    return torch.cat(embs, dim=0)

item_emb = encode_texts(movies["text"].tolist())
item_emb.shape
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# torch.Size([3883, 768])

# %% [markdown]
# ### 2.6. Save item embedding as tensor

# %%
save_path = "./ml-1m/item_emb.pt"
torch.save(item_emb, save_path)

# later
item_emb2 = torch.load(save_path, map_location="cpu")
print(item_emb2.shape)
# Out:
# torch.Size([3883, 768])

# %%
payload = {
    "item_emb": item_emb,                      # [num_items, hidden_dim]
    "movie_id": movies["movie_id"].to_numpy(), # same order as embeddings
}
torch.save(payload, "./ml-1m/item_emb_with_ids.pt")

# later
obj = torch.load("./ml-1m/item_emb_with_ids.pt", map_location="cpu", weights_only=False)
item_emb = obj["item_emb"]
movie_id = obj["movie_id"]

# %%
import torch.nn.functional as F

# normalize for cosine similarity
E = F.normalize(item_emb, p=2, dim=1)

movieid_to_row = {mid:i for i,mid in enumerate(movies["movie_id"].tolist())}

def similar_movies(movie_id, topk=10):
    i = movieid_to_row[movie_id]
    sims = (E @ E[i]).numpy()
    top = sims.argsort()[::-1][1:topk+1]  # exclude itself
    return movies.iloc[top][["movie_id","title","genres"]]

similar_movies(movie_id=1, topk=10)  # Toy Story is movie_id=1 in ml-1m
# Out:
#       movie_id                                   title  \
# 3045      3114                      Toy Story 2 (1999)
# 3682      3751                      Chicken Run (2000)
# 1050      1064  Aladdin and the King of Thieves (1996)
# 584        588                          Aladdin (1992)
# 2286      2355                    Bug's Life, A (1998)
# 1743      1806                           Paulie (1998)
# 2069      2138                   Watership Down (1978)
# 591        595             Beauty and the Beast (1991)
# 2072      2141                American Tail, An (1986)
# 451        455                       Free Willy (1993)
#
#                                    genres
# 3045          Animation|Children's|Comedy
# 3682          Animation|Children's|Comedy
# 1050          Animation|Children's|Comedy
# 584   Animation|Children's|Comedy|Musical
# 2286          Animation|Children's|Comedy
# 1743          Adventure|Children's|Comedy
# 2069   Animation|Children's|Drama|Fantasy
# 591          Animation|Children's|Musical
# 2072          Animation|Children's|Comedy
# 451            Adventure|Children's|Drama

# %%
from collections import defaultdict
import numpy as np

liked = train.groupby("user_id")["movie_id"].apply(list).to_dict()

def recommend_for_user_content(user_id, topk=10):
    mids = liked.get(user_id, [])
    mids = [m for m in mids if m in movieid_to_row]
    if not mids: 
        return None
    rows = [movieid_to_row[m] for m in mids]
    u = E[rows].mean(dim=0, keepdim=True)
    sims = (E @ u[0]).numpy()
    # filter already seen
    seen_rows = set(rows)
    candidates = [i for i in sims.argsort()[::-1] if i not in seen_rows]
    top = candidates[:topk]
    return movies.iloc[top][["movie_id","title","genres"]]

recommend_for_user_content(user_ids[0], topk=10)
# Out:
#       movie_id                 title           genres
# 3038      3107      Backdraft (1991)     Action|Drama
# 3099      3168     Easy Rider (1969)  Adventure|Drama
# 1096      1112   Palookaville (1996)     Action|Drama
# 651        657    Yankee Zulu (1994)     Comedy|Drama
# 1885      1954          Rocky (1976)     Action|Drama
# 2857      2926      Hairspray (1988)     Comedy|Drama
# 2508      2577      Metroland (1997)     Comedy|Drama
# 3096      3165  Boiling Point (1993)     Action|Drama
# 533        537         Sirens (1994)     Comedy|Drama
# 3457      3526     Parenthood (1989)     Comedy|Drama

# %%
# item2idx maps movie_id -> item_idx used by X_ui / eval_model
idx2item = {i:m for m,i in item2idx.items()}

# Build a matrix of embeddings in item-index order (0..num_items-1)
# Assumes you have:
# - E: normalized embeddings for ALL movies in `movies` dataframe (same order as movies rows)
# - movieid_to_row: mapping movie_id -> row index in `movies`/E
# If you don't already have E/movieid_to_row, see the note below.

# If you have `item_emb` as torch tensor [num_movies_all, 768]:
E_all = F.normalize(item_emb, p=2, dim=1)

movieid_to_row = {mid:i for i,mid in enumerate(movies["movie_id"].tolist())}

num_items = len(item2idx)
dim = E_all.shape[1]
E_items = torch.empty((num_items, dim), dtype=E_all.dtype)

missing = 0
for item_idx in range(num_items):
    mid = idx2item[item_idx]
    row = movieid_to_row.get(mid, None)
    if row is None:
        missing += 1
        E_items[item_idx] = 0
    else:
        E_items[item_idx] = E_all[row]

print("missing movies:", missing, "out of", num_items)
# Out:
# missing movies: 0 out of 3530

# %% [markdown]
# ## Lab Assignment
# 1. Complete the recommend functions powered by BERT Content Embedding.
# 2. Try at least 2 different pre-trained model for embedding and test the model performance.

# %%
class BertContentModel:
    def __init__(self, E_items):
        # E_items: torch tensor [num_items, dim], already normalized
        self.E = F.normalize(E_items, p=2, dim=1)

    def recommend(self, u_idx, X_ui, N=10):
        
        # Get items user interacted with from sparse matrix row
        user_row = X_ui    
        seen_indices = user_row.nonzero()[1] 

        # Edge cases: the user has no seen movies
        if len(seen_indices) == 0:
            top = torch.randperm(self.E.shape[0])[:N]
            return [(int(i), 0.0) for i in top]
            
        # User embedding = mean of seen item embeddings
        seen_embs = self.E[seen_indices]    
        u_emb = seen_embs.mean(dim=0) 
        u_emb = F.normalize(u_emb, p=2, dim=0)

        # Top-N
        scores = self.E @ u_emb            
        scores[seen_indices] = -1.0       
        
        top_idx = torch.topk(scores, k=N).indices

        return [(int(i), float(scores[i])) for i in top_idx]

# %%
bert_model = BertContentModel(E_items)

# %%
eval_model(bert_model, X_ui, test, K=10)
# Out:
# {'Recall@K': 0.01557838912827312,
#  'NDCG@K': 0.007848329700857354,
#  'Users': 6034}

# %%
pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Obtaining dependency information for sentence_transformers from https://files.pythonhosted.org/packages/c5/d9/3a9b6f2ccdedc9dc00fe37b2fc58f58f8efbff44565cf4bf39d8568bb13a/sentence_transformers-5.4.1-py3-none-any.whl.metadata
#   Downloading sentence_transformers-5.4.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (5.7.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.13.0)
# Requirement already satisfied: torch>=1.11.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (2.11.0)
# Requirement already satisfied: numpy>=1.20.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.26.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.11.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (6.0)
# Requirement already satisfied: typer in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (0.25.1)
# Requirement already satisfied: joblib>=1.3.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22.0->sentence_transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22.0->sentence_transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (68.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->sentence_transformers) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->sentence_transformers) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->sentence_transformers) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->sentence_transformers) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->sentence_transformers) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->sentence_transformers) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->sentence_transformers) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->sentence_transformers) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->sentence_transformers) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->sentence_transformers) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->sentence_transformers) (13.0.85)
# Requirement already satisfied: regex>=2025.10.22 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (0.7.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from cuda-bindings<14,>=13.0.3->torch>=1.11.0->sentence_transformers) (1.5.4)
# Requirement already satisfied: anyio in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence_transformers) (3.5.0)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence_transformers) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence_transformers) (1.0.9)
# Requirement already satisfied: idna in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence_transformers) (3.4)
# Requirement already satisfied: h11>=0.16 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence_transformers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.1)
# Requirement already satisfied: click>=8.2.1 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from typer->huggingface-hub>=0.23.0->sentence_transformers) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from typer->huggingface-hub>=0.23.0->sentence_transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from typer->huggingface-hub>=0.23.0->sentence_transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from typer->huggingface-hub>=0.23.0->sentence_transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from rich>=13.8.0->typer->huggingface-hub>=0.23.0->sentence_transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from rich>=13.8.0->typer->huggingface-hub>=0.23.0->sentence_transformers) (2.15.1)
# Requirement already satisfied: sniffio>=1.1 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence_transformers) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ec2-user/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->huggingface-hub>=0.23.0->sentence_transformers) (0.1.0)
# Downloading sentence_transformers-5.4.1-py3-none-any.whl (571 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.3/571.3 kB 17.3 MB/s eta 0:00:00
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-5.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer
sbert = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
item_emb_minilm = torch.tensor(
    sbert.encode(movies["text"].tolist(), batch_size=64, show_progress_bar=True))  

E_items_minilm = F.normalize(item_emb_minilm, p=2, dim=1)[
    [movieid_to_row.get(idx2item[i], 0) for i in range(len(item2idx))]]
# Out:
# Batches:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
model_minilm = BertContentModel(E_items_minilm)

# %%
eval_model(model_minilm, X_ui, test, K=10)
# Out:
# {'Recall@K': 0.012263838249917136,
#  'NDCG@K': 0.005970141120406683,
#  'Users': 6034}
